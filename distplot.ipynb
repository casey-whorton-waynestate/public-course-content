# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/casey/Downloads/winequality-red.csv')

# %%
df[['total sulfur dioxide','density']].describe()
# Out:
#        total sulfur dioxide      density
# count           1599.000000  1599.000000
# mean              46.467792     0.996747
# std               32.895324     0.001887
# min                6.000000     0.990070
# 25%               22.000000     0.995600
# 50%               38.000000     0.996750
# 75%               62.000000     0.997835
# max              289.000000     1.003690

# %%
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.distplot(df['total sulfur dioxide'])
plt.title('total sulfur dioxide')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
sns.distplot(np.log(df['total sulfur dioxide']))
plt.title('ln(total sulfur dioxide)')
plt.show()

# %%
x1 = (np.arange(1,1000,1))
x2 = np.log(x1)
plt.scatter(x = x1, y = x2, linestyle ='-', marker = 'o')
plt.show()

# %%
x1 = (np.arange(1,1000,1))
x2 = np.log(x1)
plt.scatter(x = x1, y = x1, linestyle ='-', marker = 'o')
plt.show()

# %%
sns.distplot(df['density'])

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(20,3))
df['citric acid'].rolling(window=6).mean().plot()
plt.show()

# %%
plt.figure(figsize=(5,5))
df['citric acid'].rolling(window=6).mean().plot()
plt.show()

# %%
plt.bar(x= df.quality, height = df['citric acid'])
plt.show()

# %%
plt.bar(x= df.quality, height = df['citric acid'])
plt.show()

# %%
sns.distplot(100/df.iloc[:,10],bins=10)
import matplotlib.pyplot as plt
plt.xlabel('100/alcohol')
# Out:
# Text(0.5, 0, '100/alcohol')

# %%
sns.boxplot(y = df['density'])

# %%
df['fixed acidity'][0] = -999
# Out:
# C:\Users\casey\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        7.690244          0.527821     0.270976        2.538806
# std        25.250965          0.179060     0.194801        1.409928
# min      -999.000000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...
